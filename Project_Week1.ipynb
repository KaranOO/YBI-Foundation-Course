# %% [markdown]
# Importing Libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# Reading CSV File

# %%
df = pd.read_csv('https://gist.githubusercontent.com/rnirmal/e01acfdaf54a6f9b24e91ba4cae63518/raw/6b589a5c5a851711e20c5eb28f9d54742d1fe2dc/datasets.csv')
df
# Out:
#            datasetName                                            about  \
# 0   Microbiome Project                American Gut (Microbiome Project)
# 1                GloBI               Global Biotic Interactions (GloBI)
# 2       Global Climate                   Global Climate Data Since 1929
# 3      CommonCraw 2012              3.5B Web Pages from CommonCraw 2012
# 4    Indiana Webclicks  53.5B Web clicks of 100K users in Indiana Univ.
# ..                 ...                                              ...
# 56      ClueWeb12 FACC                                   ClueWeb12 FACC
# 57       Google Ngrams                      Google Books Ngrams (2.2TB)
# 58          EDRM Enron      EDRM Enron EMail of 151 users, hosted on S3
# 59             GetGlue                  GetGlue - users rating TV shows
# 60      Twitter RepLab    Twitter Data for Online Reputation Management
#
#                                                  link       categoryName  \
# ...

# %% [markdown]
# Info about Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datasetName   61 non-null     object
#  1   about         61 non-null     object
#  2   link          61 non-null     object
#  3   categoryName  61 non-null     object
#  4   cloud         24 non-null     object
#  5   vintage       31 non-null     float64
# dtypes: float64(1), object(5)
# memory usage: 3.0+ KB

# %%
df.describe()
# Out:
#            vintage
# count    31.000000
# mean   2000.677419
# std      24.436840
# min    1920.000000
# 25%    2006.500000
# 50%    2009.000000
# 75%    2012.000000
# max    2016.000000

# %% [markdown]
# Checking for total num values

# %%
df.isna().sum()
# Out:
# datasetName      0
# about            0
# link             0
# categoryName     0
# cloud           37
# vintage         30
# dtype: int64

# %%
df.columns
# Out:
# Index(['datasetName', 'about', 'link', 'categoryName', 'cloud', 'vintage'], dtype='object')

# %%
df.dropna()
# Out:
#             datasetName                                            about  \
# 32  FBI Hate Crime 2013            FBI Hate Crime 2013 - aggregated data
# 41             NYC Uber  NYC Uber trip data April 2014 to September 2014
#
#                                                  link     categoryName  \
# 32  https://github.com/emorisse/FBI-Hate-Crime-Sta...  Social Sciences
# 41  https://github.com/fivethirtyeight/uber-tlc-fo...   Transportation
#
#      cloud  vintage
# 32  GitHub   2013.0
# 41  GitHub   2014.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datasetName   61 non-null     object
#  1   about         61 non-null     object
#  2   link          61 non-null     object
#  3   categoryName  61 non-null     object
#  4   cloud         24 non-null     object
#  5   vintage       31 non-null     float64
# dtypes: float64(1), object(5)
# memory usage: 3.0+ KB

# %%
df.shape
# Out:
# (61, 6)

# %%
df.isna()
# Out:
#     datasetName  about   link  categoryName  cloud  vintage
# 0         False  False  False         False  False     True
# 1         False  False  False         False  False     True
# 2         False  False  False         False   True    False
# 3         False  False  False         False   True    False
# 4         False  False  False         False   True     True
# ..          ...    ...    ...           ...    ...      ...
# 56        False  False  False         False   True    False
# 57        False  False  False         False  False     True
# 58        False  False  False         False  False     True
# 59        False  False  False         False   True     True
# 60        False  False  False         False   True    False
#
# [61 rows x 6 columns]

# %%
pd.options.display.max_rows=90
df
# Out:
#                    datasetName  \
# 0           Microbiome Project
# 1                        GloBI
# 2               Global Climate
# 3              CommonCraw 2012
# 4            Indiana Webclicks
# 5         Criteo click-through
# 6                   ICWSM 2009
# 7                      KDD Cup
# 8              Localytics Data
# 9                 Yelp Dataset
# 10         Bruteforce Database
# 11                   Countries
# 12                   TwoFishes
# 13             World countries
# 14        Cities and countries
# 15                 Ebola cases
# 16                 eBay Online
# 17         New Yorker Captions
# 18  Cooper-Hewitt's Collection
# 19       Minneapolis Institute
# 20             Tate Collection
# 21                Google 5gram
# 22        Arabic, 30K articles
# 23             USENET postings
# 24                  Datahub.io
# 25         Twitter Scrape CIKM
# 26               Facebook Data
# 27                  LAW graphs
# 28             Foursquare from
# ...

# %% [markdown]
# Replacing NULL values with understandable elements. i.e others(for clouds), 0(for vintage)

# %%
df['cloud'] = df['cloud'].fillna("others")
df
# Out:
#                    datasetName  \
# 0           Microbiome Project
# 1                        GloBI
# 2               Global Climate
# 3              CommonCraw 2012
# 4            Indiana Webclicks
# 5         Criteo click-through
# 6                   ICWSM 2009
# 7                      KDD Cup
# 8              Localytics Data
# 9                 Yelp Dataset
# 10         Bruteforce Database
# 11                   Countries
# 12                   TwoFishes
# 13             World countries
# 14        Cities and countries
# 15                 Ebola cases
# 16                 eBay Online
# 17         New Yorker Captions
# 18  Cooper-Hewitt's Collection
# 19       Minneapolis Institute
# 20             Tate Collection
# 21                Google 5gram
# 22        Arabic, 30K articles
# 23             USENET postings
# 24                  Datahub.io
# 25         Twitter Scrape CIKM
# 26               Facebook Data
# 27                  LAW graphs
# 28             Foursquare from
# ...

# %%
df['vintage'] = df['vintage'].fillna(0000.0)
df
# Out:
#                    datasetName  \
# 0           Microbiome Project
# 1                        GloBI
# 2               Global Climate
# 3              CommonCraw 2012
# 4            Indiana Webclicks
# 5         Criteo click-through
# 6                   ICWSM 2009
# 7                      KDD Cup
# 8              Localytics Data
# 9                 Yelp Dataset
# 10         Bruteforce Database
# 11                   Countries
# 12                   TwoFishes
# 13             World countries
# 14        Cities and countries
# 15                 Ebola cases
# 16                 eBay Online
# 17         New Yorker Captions
# 18  Cooper-Hewitt's Collection
# 19       Minneapolis Institute
# 20             Tate Collection
# 21                Google 5gram
# 22        Arabic, 30K articles
# 23             USENET postings
# 24                  Datahub.io
# 25         Twitter Scrape CIKM
# 26               Facebook Data
# 27                  LAW graphs
# 28             Foursquare from
# ...

# %%
pd.options.display.max_rows=10
df
# Out:
#            datasetName                                            about  \
# 0   Microbiome Project                American Gut (Microbiome Project)
# 1                GloBI               Global Biotic Interactions (GloBI)
# 2       Global Climate                   Global Climate Data Since 1929
# 3      CommonCraw 2012              3.5B Web Pages from CommonCraw 2012
# 4    Indiana Webclicks  53.5B Web clicks of 100K users in Indiana Univ.
# ..                 ...                                              ...
# 56      ClueWeb12 FACC                                   ClueWeb12 FACC
# 57       Google Ngrams                      Google Books Ngrams (2.2TB)
# 58          EDRM Enron      EDRM Enron EMail of 151 users, hosted on S3
# 59             GetGlue                  GetGlue - users rating TV shows
# 60      Twitter RepLab    Twitter Data for Online Reputation Management
#
#                                                  link       categoryName  \
# ...

# %% [markdown]
# Indexing from 1

# %%
df.index +=1
df
# Out:
#            datasetName                                            about  \
# 1   Microbiome Project                American Gut (Microbiome Project)
# 2                GloBI               Global Biotic Interactions (GloBI)
# 3       Global Climate                   Global Climate Data Since 1929
# 4      CommonCraw 2012              3.5B Web Pages from CommonCraw 2012
# 5    Indiana Webclicks  53.5B Web clicks of 100K users in Indiana Univ.
# ..                 ...                                              ...
# 57      ClueWeb12 FACC                                   ClueWeb12 FACC
# 58       Google Ngrams                      Google Books Ngrams (2.2TB)
# 59          EDRM Enron      EDRM Enron EMail of 151 users, hosted on S3
# 60             GetGlue                  GetGlue - users rating TV shows
# 61      Twitter RepLab    Twitter Data for Online Reputation Management
#
#                                                  link       categoryName  \
# ...

# %% [markdown]
# Representation of clouds servies used

# %%
df['cloud'].unique()
# Out:
# array(['GitHub', 'others', 'Amazon'], dtype=object)

# %%
Pie_rep = df['cloud'].value_counts()
fig, ax = plt.subplots(facecolor="#db7940", figsize=(8,8))
plt.pie(Pie_rep, labels=cld)
plt.show()

# %% [markdown]
# Query to show Biology category categoryName used GitHub cloud services

# %%
n1 = df['cloud']=="GitHub"
n2 = df['categoryName']=="Biology"
df[n1 & n2]
# Out:
#           datasetName                               about  \
# 1  Microbiome Project   American Gut (Microbiome Project)
# 2               GloBI  Global Biotic Interactions (GloBI)
#
#                                                 link categoryName   cloud  \
# 1            https://github.com/biocore/American-Gut      Biology  GitHub
# 2  https://github.com/jhpoelen/eol-globi-data/wik...      Biology  GitHub
#
#    vintage
# 1      0.0
# 2      0.0

# %%
print(df[df['cloud']=="others"]['about'])
# Out:
# 3                      Global Climate Data Since 1929
# 4                 3.5B Web Pages from CommonCraw 2012
# 5     53.5B Web clicks of 100K users in Indiana Univ.
# 6                           Criteo click-through data
# 7                   ICWSM Data Challenge (since 2009)
#                            ...
# 55                        10k US Adult Faces Database
# 56                                     ClueWeb09 FACC
# 57                                     ClueWeb12 FACC
# 60                    GetGlue - users rating TV shows
# 61      Twitter Data for Online Reputation Management
# Name: about, Length: 37, dtype: object

# %% [markdown]
# To see what is in 2nd index; (indexing begins with 0)

# %%
df.iloc[2]
# Out:
# datasetName                     Global Climate
# about           Global Climate Data Since 1929
# link            http://en.tutiempo.net/climate
# categoryName                   Climate/Weather
# cloud                                   others
# vintage                                 1929.0
# Name: 3, dtype: object

# %% [markdown]
# indexing begins with 1

# %%
df.loc[2]
# Out:
# datasetName                                                 GloBI
# about                          Global Biotic Interactions (GloBI)
# link            https://github.com/jhpoelen/eol-globi-data/wik...
# categoryName                                              Biology
# cloud                                                      GitHub
# vintage                                                       0.0
# Name: 2, dtype: object

# %%
df.head()
# Out:
#           datasetName                                            about  \
# 1  Microbiome Project                American Gut (Microbiome Project)
# 2               GloBI               Global Biotic Interactions (GloBI)
# 3      Global Climate                   Global Climate Data Since 1929
# 4     CommonCraw 2012              3.5B Web Pages from CommonCraw 2012
# 5   Indiana Webclicks  53.5B Web clicks of 100K users in Indiana Univ.
#
#                                                 link       categoryName  \
# 1            https://github.com/biocore/American-Gut            Biology
# 2  https://github.com/jhpoelen/eol-globi-data/wik...            Biology
# 3                     http://en.tutiempo.net/climate    Climate/Weather
# 4  http://www.bigdatanews.com/profiles/blogs/big-...  Computer Networks
# 5  http://cnets.indiana.edu/groups/nan/webtraffic...  Computer Networks
#
#     cloud  vintage
# 1  GitHub      0.0
# 2  GitHub      0.0
# 3  others   1929.0
# 4  others   2012.0
# ...

# %% [markdown]
# See first 8 rows of dataset

# %%
df.head(9)
# Out:
#             datasetName                                            about  \
# 1    Microbiome Project                American Gut (Microbiome Project)
# 2                 GloBI               Global Biotic Interactions (GloBI)
# 3        Global Climate                   Global Climate Data Since 1929
# 4       CommonCraw 2012              3.5B Web Pages from CommonCraw 2012
# 5     Indiana Webclicks  53.5B Web clicks of 100K users in Indiana Univ.
# 6  Criteo click-through                        Criteo click-through data
# 7            ICWSM 2009                ICWSM Data Challenge (since 2009)
# 8               KDD Cup                          KDD Cup by Tencent 2012
# 9       Localytics Data          Localytics Data Visualization Challenge
#
#                                                 link       categoryName  \
# 1            https://github.com/biocore/American-Gut            Biology
# 2  https://github.com/jhpoelen/eol-globi-data/wik...            Biology
# ...

# %% [markdown]
# see last 8 rows of dataset

# %%
df.tail(9)
# Out:
#         datasetName                                              about  \
# 53        Landsat 8                                   Landsat 8 on AWS
# 54  Reverse Geocode  Simple but fast reverse geocoding up to city g...
# 55   Faces Database                        10k US Adult Faces Database
# 56   ClueWeb09 FACC                                     ClueWeb09 FACC
# 57   ClueWeb12 FACC                                     ClueWeb12 FACC
# 58    Google Ngrams                        Google Books Ngrams (2.2TB)
# 59       EDRM Enron        EDRM Enron EMail of 151 users, hosted on S3
# 60          GetGlue                    GetGlue - users rating TV shows
# 61   Twitter RepLab      Twitter Data for Online Reputation Management
#
#                                                  link      categoryName  \
# 53   https://aws.amazon.com/public-data-sets/landsat/               GIS
# 54            https://github.com/kno10/reversegeocode               GIS
# ...

# %% [markdown]
# Most recent year data

# %%
df['vintage'].nlargest()
# Out:
# 52    2016.0
# 16    2014.0
# 42    2014.0
# 29    2013.0
# 33    2013.0
# Name: vintage, dtype: float64

# %%
df.sort_values('vintage', ascending=False)
# Out:
#                 datasetName  \
# 52                  UK-DALE
# 16              Ebola cases
# 42                 NYC Uber
# 61           Twitter RepLab
# 41              FOIA/FOILed
# ..                      ...
# 10             Yelp Dataset
# 37  Pinhooker: Thoroughbred
# 15     Cities and countries
# 39                      BSS
# 1        Microbiome Project
#
#                                                 about  \
# 52  UK Domestic Appliance-Level Electricity (UK-DA...
# 16  Number of Ebola Cases and Deaths in Affected C...
# 42    NYC Uber trip data April 2014 to September 2014
# 61      Twitter Data for Online Reputation Management
# 41              NYC Taxi Trip Data 2013 (FOIA/FOILed)
# ..                                                ...
# 10                             Yelp Dataset Challenge
# 37       Pinhooker: Thoroughbred Bloodstock Sale Data
# 15  A list of cities and countries contributed by ...
# 39                Bike Share Systems (BSS) collection
# ...
